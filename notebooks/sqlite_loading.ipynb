# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///bluestock_mf.db")

# %%
funds_df = pd.read_csv('../data/raw/01_fund_master.csv')
facts_nav_df = pd.read_csv('../data/processed/nav_history_cleaned.csv')
funds_trans_df = pd.read_csv('../data/processed/investor_transaction.csv')
funds_perf_df = pd.read_csv('../data/processed/scheme_performance.csv')
funds_aum_df = pd.read_csv('../data/raw/03_aum_by_fund_house.csv')
fact_sip_df = pd.read_csv('../data/raw/04_monthly_sip_inflows.csv')

# %%
date_df = pd.DataFrame()
date_df['date'] = pd.to_datetime(facts_nav_df['date'].unique())

date_df['year'] = date_df['date'].dt.year
date_df['month'] = date_df['date'].dt.month
date_df['day'] = date_df['date'].dt.day
date_df['quarter'] = date_df['date'].dt.quarter
date_df['day_name'] = date_df['date'].dt.day_name()

# %%
funds_df.to_sql("dim_fund",engine,if_exists= "replace",index = False)
facts_nav_df.to_sql("fact_nav",engine,if_exists= "replace",index = False)
funds_trans_df.to_sql("fact_transactions",engine,if_exists= "replace",index = False)
funds_perf_df.to_sql("fact_performance",engine,if_exists= "replace",index = False)
funds_aum_df.to_sql("fact_aum",engine,if_exists= "replace",index = False)
date_df.to_sql("dim_date", engine, if_exists="replace", index=False)
fact_sip_df.to_sql("fact_sip_inflows", engine, if_exists="replace", index=False)
# Out:
# 48

# %%
print("Rows in dim_fund csv file : ",len(funds_df))
print("dim_date CSV rows:", len(date_df))
print("Rows in facts_nav_df csv file : ",len(facts_nav_df))
print("fact_transactions CSV rows:", len(funds_trans_df))
print("fact_performance CSV rows:", len(funds_perf_df))
print("fact_aum CSV rows:", len(funds_aum_df))
# Out:
# Rows in dim_fund csv file :  40
# dim_date CSV rows: 1150
# Rows in facts_nav_df csv file :  46000
# fact_transactions CSV rows: 32778
# fact_performance CSV rows: 40
# fact_aum CSV rows: 90

# %%
print(pd.read_sql("SELECT COUNT(*) as count_dim_fund FROM dim_fund", engine))
print(pd.read_sql("SELECT COUNT(*) as count_dim_date FROM dim_date", engine))
print(pd.read_sql("SELECT COUNT(*) as count_fact_nav FROM fact_nav", engine))
print(pd.read_sql("SELECT COUNT(*) as count_fact_transaction FROM fact_transactions", engine))
print(pd.read_sql("SELECT COUNT(*) as count_fact_performace FROM fact_performance", engine))
print(pd.read_sql("SELECT COUNT(*) as count_fact_aum FROM fact_aum", engine))
# Out:
#    count_dim_fund
# 0              40
#    count_dim_date
# 0            1150
#    count_fact_nav
# 0           46000
#    count_fact_transaction
# 0                   32778
#    count_fact_performace
# 0                     40
#    count_fact_aum
# 0              90

# %% [markdown]
# ### Observation
#
# - The row counts of the database tables are equal to the row counts of the source CSV files.
# - Therefore, the data loading process was completed successfully.

# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nDatabase absolute path:")
print(os.path.abspath("bluestock_mf.db"))
# Out:
# Current working directory:
# c:\Users\laksh\OneDrive\Documents\GitHub\Mutual_Fund_Project\notebooks
#
# Database absolute path:
# c:\Users\laksh\OneDrive\Documents\GitHub\Mutual_Fund_Project\notebooks\bluestock_mf.db
